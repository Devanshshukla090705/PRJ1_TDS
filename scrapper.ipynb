# %%
import requests
import pandas as pd

# GitHub API token (replace 'your_token_here' with your actual token)
token = "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"
headers = {"Authorization": f"token {token}"}

# Function to fetch users with pagination
def fetch_users(city, min_followers):
    users = []
    page = 1

    while True:
        print(f"Fetching page {page}...")
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>={min_followers}&per_page=100&page={page}"
        response = requests.get(url, headers=headers)

        if response.status_code != 200:
            print(f"Error: {response.status_code} - {response.json()}")
            break

        data = response.json().get("items", [])
        if not data:
            break  # No more data, exit the loop

        users.extend(data)
        page += 1

    return users

# Function to fetch repositories for a given user (up to 500 most recent)
def fetch_repositories(username):
    repos = []
    page = 1

    while True:
        print(f"Fetching repositories for {username}, page {page}...")
        url = f"https://api.github.com/users/{username}/repos?per_page=100&page={page}"
        response = requests.get(url, headers=headers)

        if response.status_code != 200:
            print(f"Error fetching repos for {username}: {response.status_code}")
            break

        data = response.json()
        if not data:
            break  # No more repositories, exit the loop

        repos.extend(data)
        page += 1

    return repos

# Helper function to clean company names
def clean_company_name(company):
    if not company:
        return ""
    return company.strip().lstrip('@').upper()

# Fetch all users in Chicago with 100+ followers
users_data = fetch_users(city="Chicago", min_followers=100)
print(f"Total users fetched: {len(users_data)}")

# Prepare user data for users.csv
users_list = []
repos_list = []

for user in users_data:
    username = user["login"]
    user_info = {
        "login": user["login"],
        "name": user.get("name", ""),
        "company": clean_company_name(user.get("company", "")),
        "location": user.get("location", ""),
        "email": user.get("email", ""),
        "hireable": str(user.get("hireable", "")),
        "bio": user.get("bio", ""),
        "public_repos": user.get("public_repos", 0),
        "followers": user.get("followers", 0),
        "following": user.get("following", 0),
        "created_at": user.get("created_at", "")
    }
    users_list.append(user_info)

    # Fetch repositories for each user and prepare data for repositories.csv
    user_repos = fetch_repositories(username)
    for repo in user_repos:
        license_info = repo.get("license")  # Handle license being None

        repo_info = {
            "login": username,
            "full_name": repo["full_name"],
            "created_at": repo["created_at"],
            "stargazers_count": repo["stargazers_count"],
            "watchers_count": repo["watchers_count"],
            "language": repo.get("language", ""),
            "has_projects": repo["has_projects"],
            "has_wiki": repo["has_wiki"],
            "license_name": license_info["key"] if license_info else ""
        }
        repos_list.append(repo_info)

# Save users data to users.csv
users_df = pd.DataFrame(users_list)
users_df.to_csv("users.csv", index=False)
print("Saved users.csv successfully!")

# Save repositories data to repositories.csv
repos_df = pd.DataFrame(repos_list)
repos_df.to_csv("repositories.csv", index=False)
print("Saved repositories.csv successfully!")

# Create README.md with the three bullet points
with open("README.md", "w") as f:
    f.write("- This project scraped data from GitHub using the GitHub API, focusing on users in Chicago with 100+ followers.\n")
    f.write("- One surprising finding is that a significant number of developers in Chicago do not use licenses for their repositories.\n")
    f.write("- Developers should consider adding licenses to their repositories to encourage collaboration and clarify usage terms.\n")

print("README.md created successfully!")
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Total users fetched: 380
# Fetching repositories for cassidoo, page 1...
# Fetching repositories for cassidoo, page 2...
# Fetching repositories for cassidoo, page 3...
# Fetching repositories for felangel, page 1...
# Fetching repositories for felangel, page 2...
# Fetching repositories for felangel, page 3...
# Fetching repositories for dabeaz, page 1...
# Fetching repositories for dabeaz, page 2...
# Fetching repositories for sstephenson, page 1...
# Fetching repositories for sstephenson, page 2...
# Fetching repositories for mattgodbolt, page 1...
# Fetching repositories for mattgodbolt, page 2...
# Fetching repositories for logankilpatrick, page 1...
# Fetching repositories for logankilpatrick, page 2...
# Fetching repositories for logankilpatrick, page 3...
# Fetching repositories for logankilpatrick, page 4...
# Fetching repositories for khan4019, page 1...
# Fetching repositories for khan4019, page 2...
# Fetching repositories for khan4019, page 3...
# Fetching repositories for adashofdata, page 1...
# Fetching repositories for adashofdata, page 2...
# Fetching repositories for djspiewak, page 1...
# Fetching repositories for djspiewak, page 2...
# Fetching repositories for djspiewak, page 3...
# Fetching repositories for eddelbuettel, page 1...
# Fetching repositories for eddelbuettel, page 2...
# Fetching repositories for eddelbuettel, page 3...
# Fetching repositories for eddelbuettel, page 4...
# Fetching repositories for eddelbuettel, page 5...
# Fetching repositories for eddelbuettel, page 6...
# Fetching repositories for natemoo-re, page 1...
# Fetching repositories for natemoo-re, page 2...
# Fetching repositories for natemoo-re, page 3...
# Fetching repositories for natemoo-re, page 4...
# Fetching repositories for lexi-lambda, page 1...
# Fetching repositories for lexi-lambda, page 2...
# Fetching repositories for lexi-lambda, page 3...
# Fetching repositories for neodigm, page 1...
# Fetching repositories for neodigm, page 2...
# Fetching repositories for neodigm, page 3...
# Fetching repositories for neodigm, page 4...
# Fetching repositories for neodigm, page 5...
# Fetching repositories for neodigm, page 6...
# Fetching repositories for rentzsch, page 1...
# Fetching repositories for rentzsch, page 2...
# Fetching repositories for rentzsch, page 3...
# Fetching repositories for HFTrader, page 1...
# Fetching repositories for HFTrader, page 2...
# Fetching repositories for HFTrader, page 3...
# Fetching repositories for JimLiu, page 1...
# Fetching repositories for JimLiu, page 2...
# Fetching repositories for JimLiu, page 3...
# Fetching repositories for JimLiu, page 4...
# Fetching repositories for jcs, page 1...
# Fetching repositories for jcs, page 2...
# Fetching repositories for jbranchaud, page 1...
# Fetching repositories for jbranchaud, page 2...
# Fetching repositories for jbranchaud, page 3...
# Fetching repositories for basecamp, page 1...
# Fetching repositories for basecamp, page 2...
# Fetching repositories for basecamp, page 3...
# Fetching repositories for SciSharp, page 1...
# Fetching repositories for SciSharp, page 2...
# Fetching repositories for joshdholtz, page 1...
# Fetching repositories for joshdholtz, page 2...
# Fetching repositories for joshdholtz, page 3...
# Fetching repositories for joshdholtz, page 4...
# Fetching repositories for johnpolacek, page 1...
# Fetching repositories for johnpolacek, page 2...
# Fetching repositories for johnpolacek, page 3...
# Fetching repositories for davidteather, page 1...
# Fetching repositories for davidteather, page 2...
# Fetching repositories for jeremyckahn, page 1...
# Fetching repositories for jeremyckahn, page 2...
# Fetching repositories for jeremyckahn, page 3...
# Fetching repositories for dchelimsky, page 1...
# Fetching repositories for dchelimsky, page 2...
# Fetching repositories for dchelimsky, page 3...
# Fetching repositories for coreyhaines, page 1...
# Fetching repositories for coreyhaines, page 2...
# Fetching repositories for coreyhaines, page 3...
# Fetching repositories for rharter, page 1...
# Fetching repositories for rharter, page 2...
# Fetching repositories for rharter, page 3...
# Fetching repositories for rharter, page 4...
# Fetching repositories for harperreed, page 1...
# Fetching repositories for harperreed, page 2...
# Fetching repositories for harperreed, page 3...
# Fetching repositories for sksamuel, page 1...
# Fetching repositories for sksamuel, page 2...
# Fetching repositories for leeoniya, page 1...
# Fetching repositories for leeoniya, page 2...
# Fetching repositories for leeoniya, page 3...
# Fetching repositories for hwayne, page 1...
# Fetching repositories for hwayne, page 2...
# Fetching repositories for CoralineAda, page 1...
# Fetching repositories for CoralineAda, page 2...
# Fetching repositories for CoralineAda, page 3...
# Fetching repositories for sean-codes, page 1...
# Fetching repositories for sean-codes, page 2...
# Fetching repositories for gjreda, page 1...
# Fetching repositories for gjreda, page 2...
# Fetching repositories for jameslamb, page 1...
# Fetching repositories for jameslamb, page 2...
# Fetching repositories for djsime1, page 1...
# Fetching repositories for djsime1, page 2...
# Fetching repositories for dabeaz-course, page 1...
# Fetching repositories for dabeaz-course, page 2...
# Fetching repositories for lorenanicole, page 1...
# Fetching repositories for lorenanicole, page 2...
# Fetching repositories for lorenanicole, page 3...
# Fetching repositories for lorenanicole, page 4...
# Fetching repositories for LadyKerr, page 1...
# Fetching repositories for LadyKerr, page 2...
# Fetching repositories for LadyKerr, page 3...
# Fetching repositories for dannguyen, page 1...
# Fetching repositories for dannguyen, page 2...
# Fetching repositories for dannguyen, page 3...
# Fetching repositories for dannguyen, page 4...
# Fetching repositories for dannguyen, page 5...
# Fetching repositories for awatson1978, page 1...
# Fetching repositories for awatson1978, page 2...
# Fetching repositories for awatson1978, page 3...
# Fetching repositories for awatson1978, page 4...
# Fetching repositories for trek, page 1...
# Fetching repositories for trek, page 2...
# Fetching repositories for Valve, page 1...
# Fetching repositories for Valve, page 2...
# Fetching repositories for catarak, page 1...
# Fetching repositories for catarak, page 2...
# Fetching repositories for scopatz, page 1...
# Fetching repositories for scopatz, page 2...
# Fetching repositories for scopatz, page 3...
# Fetching repositories for scopatz, page 4...
# Fetching repositories for scopatz, page 5...
# Fetching repositories for ZeweiChu, page 1...
# Fetching repositories for ZeweiChu, page 2...
# Fetching repositories for peterpme, page 1...
# Fetching repositories for peterpme, page 2...
# Fetching repositories for peterpme, page 3...
# Fetching repositories for peterpme, page 4...
# Fetching repositories for bitsondatadev, page 1...
# Fetching repositories for bitsondatadev, page 2...
# Fetching repositories for estrattonbailey, page 1...
# Fetching repositories for estrattonbailey, page 2...
# Fetching repositories for estrattonbailey, page 3...
# Fetching repositories for phinze, page 1...
# Fetching repositories for phinze, page 2...
# Fetching repositories for phinze, page 3...
# Fetching repositories for lvh, page 1...
# Fetching repositories for lvh, page 2...
# Fetching repositories for lvh, page 3...
# Fetching repositories for jorgecoca, page 1...
# Fetching repositories for jorgecoca, page 2...
# Fetching repositories for bgardner, page 1...
# Fetching repositories for bgardner, page 2...
# Fetching repositories for adriangb, page 1...
# Fetching repositories for adriangb, page 2...
# Fetching repositories for adriangb, page 3...
# Fetching repositories for Templarian, page 1...
# Fetching repositories for Templarian, page 2...
# Fetching repositories for jamesturk, page 1...
# Fetching repositories for jamesturk, page 2...
# Fetching repositories for an0, page 1...
# Fetching repositories for an0, page 2...
# Fetching repositories for kierisi, page 1...
# Fetching repositories for kierisi, page 2...
# Fetching repositories for derekeder, page 1...
# Fetching repositories for derekeder, page 2...
# Fetching repositories for rachelbaker, page 1...
# Fetching repositories for rachelbaker, page 2...
# Fetching repositories for iSoron, page 1...
# Fetching repositories for iSoron, page 2...
# Fetching repositories for kpdecker, page 1...
# Fetching repositories for kpdecker, page 2...
# Fetching repositories for kpdecker, page 3...
# Fetching repositories for themeteorchef, page 1...
# Fetching repositories for themeteorchef, page 2...
# Fetching repositories for gk5885, page 1...
# Fetching repositories for gk5885, page 2...
# Fetching repositories for austinsonger, page 1...
# Fetching repositories for austinsonger, page 2...
# Fetching repositories for austinsonger, page 3...
# Fetching repositories for austinsonger, page 4...
# Fetching repositories for austinsonger, page 5...
# Fetching repositories for austinsonger, page 6...
# Fetching repositories for austinsonger, page 7...
# Fetching repositories for austinsonger, page 8...
# Fetching repositories for austinsonger, page 9...
# Fetching repositories for austinsonger, page 10...
# Fetching repositories for bwya77, page 1...
# Fetching repositories for bwya77, page 2...
# Fetching repositories for ELLIOTTCABLE, page 1...
# Fetching repositories for ELLIOTTCABLE, page 2...
# Fetching repositories for ELLIOTTCABLE, page 3...
# Fetching repositories for ELLIOTTCABLE, page 4...
# Fetching repositories for tqbf, page 1...
# Fetching repositories for tqbf, page 2...
# Fetching repositories for vehbiu, page 1...
# Fetching repositories for vehbiu, page 2...
# Fetching repositories for mjskay, page 1...
# Fetching repositories for mjskay, page 2...
# Fetching repositories for mapmeld, page 1...
# Fetching repositories for mapmeld, page 2...
# Fetching repositories for mapmeld, page 3...
# Fetching repositories for mapmeld, page 4...
# Fetching repositories for carolynvs, page 1...
# Fetching repositories for carolynvs, page 2...
# Fetching repositories for carolynvs, page 3...
# Fetching repositories for carolynvs, page 4...
# Fetching repositories for DashBarkHuss, page 1...
# Fetching repositories for DashBarkHuss, page 2...
# Fetching repositories for zigurous, page 1...
# Fetching repositories for zigurous, page 2...
# Fetching repositories for brandonleegit, page 1...
# Fetching repositories for brandonleegit, page 2...
# Fetching repositories for rsese, page 1...
# Fetching repositories for rsese, page 2...
# Fetching repositories for boonebgorges, page 1...
# Fetching repositories for boonebgorges, page 2...
# Fetching repositories for boonebgorges, page 3...
# Fetching repositories for jarry-xiao, page 1...
# Fetching repositories for jarry-xiao, page 2...
# Fetching repositories for the-raspberry-pi-guy, page 1...
# Fetching repositories for the-raspberry-pi-guy, page 2...
# Fetching repositories for saforem2, page 1...
# Fetching repositories for saforem2, page 2...
# Fetching repositories for saforem2, page 3...
# Fetching repositories for ZWMiller, page 1...
# Fetching repositories for ZWMiller, page 2...
# Fetching repositories for matagus, page 1...
# Fetching repositories for matagus, page 2...
# Fetching repositories for skwp, page 1...
# Fetching repositories for skwp, page 2...
# Fetching repositories for stevespringett, page 1...
# Fetching repositories for stevespringett, page 2...
# Fetching repositories for braverock, page 1...
# Fetching repositories for braverock, page 2...
# Fetching repositories for jenmyers, page 1...
# Fetching repositories for jenmyers, page 2...
# Fetching repositories for gar1t, page 1...
# Fetching repositories for gar1t, page 2...
# Fetching repositories for gar1t, page 3...
# Fetching repositories for gar1t, page 4...
# Fetching repositories for MarkTechson, page 1...
# Fetching repositories for MarkTechson, page 2...
# Fetching repositories for Tedko, page 1...
# Fetching repositories for Tedko, page 2...
# Fetching repositories for sabre1041, page 1...
# Fetching repositories for sabre1041, page 2...
# Fetching repositories for sabre1041, page 3...
# Fetching repositories for sabre1041, page 4...
# Fetching repositories for sabre1041, page 5...
# Fetching repositories for sabre1041, page 6...
# Fetching repositories for loganmartintran, page 1...
# Fetching repositories for loganmartintran, page 2...
# Fetching repositories for abedra, page 1...
# Fetching repositories for abedra, page 2...
# Fetching repositories for trevorturk, page 1...
# Fetching repositories for trevorturk, page 2...
# Fetching repositories for justinbmeyer, page 1...
# Fetching repositories for justinbmeyer, page 2...
# Fetching repositories for RandomFractals, page 1...
# Fetching repositories for RandomFractals, page 2...
# Fetching repositories for RandomFractals, page 3...
# Fetching repositories for srobbin, page 1...
# Fetching repositories for srobbin, page 2...
# Fetching repositories for coolbeet, page 1...
# Fetching repositories for coolbeet, page 2...
# Fetching repositories for timrwood, page 1...
# Fetching repositories for timrwood, page 2...
# Fetching repositories for shayhowe, page 1...
# Fetching repositories for shayhowe, page 2...
# Fetching repositories for ksobon, page 1...
# Fetching repositories for ksobon, page 2...
# Fetching repositories for hugs, page 1...
# Fetching repositories for hugs, page 2...
# Fetching repositories for karllhughes, page 1...
# Fetching repositories for karllhughes, page 2...
# Fetching repositories for Oceania2018, page 1...
# Fetching repositories for Oceania2018, page 2...
# Fetching repositories for emilyriederer, page 1...
# Fetching repositories for emilyriederer, page 2...
# Fetching repositories for reiddraper, page 1...
# Fetching repositories for reiddraper, page 2...
# Fetching repositories for sorentwo, page 1...
# Fetching repositories for sorentwo, page 2...
# Fetching repositories for nickvourd, page 1...
# Fetching repositories for nickvourd, page 2...
# Fetching repositories for jjhelmus, page 1...
# Fetching repositories for jjhelmus, page 2...
# Fetching repositories for jjhelmus, page 3...
# Fetching repositories for jjhelmus, page 4...
# Fetching repositories for jjhelmus, page 5...
# Fetching repositories for jjhelmus, page 6...
# Fetching repositories for ahinchman1, page 1...
# Fetching repositories for ahinchman1, page 2...
# Fetching repositories for XavierXiao, page 1...
# Fetching repositories for XavierXiao, page 2...
# Fetching repositories for coddingtonbear, page 1...
# Fetching repositories for coddingtonbear, page 2...
# Fetching repositories for coddingtonbear, page 3...
# Fetching repositories for coddingtonbear, page 4...
# Fetching repositories for stevenwanderski, page 1...
# Fetching repositories for stevenwanderski, page 2...
# Fetching repositories for JoeGermuska, page 1...
# Fetching repositories for JoeGermuska, page 2...
# Fetching repositories for JoeGermuska, page 3...
# Fetching repositories for tswast, page 1...
# Fetching repositories for tswast, page 2...
# Fetching repositories for tswast, page 3...
# Fetching repositories for MelSumner, page 1...
# Fetching repositories for MelSumner, page 2...
# Fetching repositories for MelSumner, page 3...
# Fetching repositories for MelSumner, page 4...
# Fetching repositories for MelSumner, page 5...
# Fetching repositories for greensock, page 1...
# Fetching repositories for greensock, page 2...
# Fetching repositories for ExplorerFreda, page 1...
# Fetching repositories for ExplorerFreda, page 2...
# Fetching repositories for alysivji, page 1...
# Fetching repositories for alysivji, page 2...
# Fetching repositories for alysivji, page 3...
# Fetching repositories for paulromano, page 1...
# Fetching repositories for paulromano, page 2...
# Fetching repositories for tedivm, page 1...
# Fetching repositories for tedivm, page 2...
# Fetching repositories for tedivm, page 3...
# Fetching repositories for rguthrie3, page 1...
# Fetching repositories for rguthrie3, page 2...
# Fetching repositories for FreedomWriter, page 1...
# Fetching repositories for FreedomWriter, page 2...
# Fetching repositories for FreedomWriter, page 3...
# Fetching repositories for nbriz, page 1...
# Fetching repositories for nbriz, page 2...
# Fetching repositories for CodePlatoon, page 1...
# Fetching repositories for CodePlatoon, page 2...
# Fetching repositories for mrkurt, page 1...
# Fetching repositories for mrkurt, page 2...
# Fetching repositories for kadamwhite, page 1...
# Fetching repositories for kadamwhite, page 2...
# Fetching repositories for kadamwhite, page 3...
# Fetching repositories for conorpp, page 1...
# Fetching repositories for conorpp, page 2...
# Fetching repositories for conorpp, page 3...
# Fetching repositories for Daniel-McCarthy, page 1...
# Fetching repositories for Daniel-McCarthy, page 2...
# Fetching repositories for msfrisbie, page 1...
# Fetching repositories for msfrisbie, page 2...
# Fetching repositories for bartosz-lipinski, page 1...
# Fetching repositories for bartosz-lipinski, page 2...
# Fetching repositories for ivelasq, page 1...
# Fetching repositories for ivelasq, page 2...
# Fetching repositories for joshbirk, page 1...
# Fetching repositories for joshbirk, page 2...
# Fetching repositories for pushcx, page 1...
# Fetching repositories for pushcx, page 2...
# Fetching repositories for jackdoyle, page 1...
# Fetching repositories for jackdoyle, page 2...
# Fetching repositories for brandonwillard, page 1...
# Fetching repositories for brandonwillard, page 2...
# Fetching repositories for brandonwillard, page 3...
# Fetching repositories for rrag, page 1...
# Fetching repositories for rrag, page 2...
# Fetching repositories for drewolson, page 1...
# Fetching repositories for drewolson, page 2...
# Fetching repositories for joemaddalone, page 1...
# Fetching repositories for joemaddalone, page 2...
# Fetching repositories for ionelabrinza, page 1...
# Fetching repositories for ionelabrinza, page 2...
# Fetching repositories for jamigibbs, page 1...
# Fetching repositories for jamigibbs, page 2...
# Fetching repositories for mager, page 1...
# Fetching repositories for mager, page 2...
# Fetching repositories for mikehostetler, page 1...
# Fetching repositories for mikehostetler, page 2...
# Fetching repositories for mikehostetler, page 3...
# Fetching repositories for mstruve, page 1...
# Fetching repositories for mstruve, page 2...
# Fetching repositories for jberger, page 1...
# Fetching repositories for jberger, page 2...
# Fetching repositories for jberger, page 3...
# Fetching repositories for brianboyer, page 1...
# Fetching repositories for brianboyer, page 2...
# Fetching repositories for mikewesthad, page 1...
# Fetching repositories for mikewesthad, page 2...
# Fetching repositories for mikewesthad, page 3...
# Fetching repositories for brasic, page 1...
# Fetching repositories for brasic, page 2...
# Fetching repositories for braintreeps, page 1...
# Fetching repositories for braintreeps, page 2...
# Fetching repositories for k4rtik, page 1...
# Fetching repositories for k4rtik, page 2...
# Fetching repositories for MarcosX, page 1...
# Fetching repositories for MarcosX, page 2...
# Fetching repositories for jordanorelli, page 1...
# Fetching repositories for jordanorelli, page 2...
# Fetching repositories for FormerLurker, page 1...
# Fetching repositories for FormerLurker, page 2...
# Fetching repositories for syngenta-digital, page 1...
# Fetching repositories for syngenta-digital, page 2...
# Fetching repositories for samanthamichele7, page 1...
# Fetching repositories for samanthamichele7, page 2...
# Fetching repositories for arsho, page 1...
# Fetching repositories for arsho, page 2...
# Fetching repositories for dremin, page 1...
# Fetching repositories for dremin, page 2...
# Fetching repositories for jdingel, page 1...
# Fetching repositories for jdingel, page 2...
# Fetching repositories for keeleysam, page 1...
# Fetching repositories for keeleysam, page 2...
# Fetching repositories for Athlon1600, page 1...
# Fetching repositories for Athlon1600, page 2...
# Fetching repositories for tighten, page 1...
# Fetching repositories for tighten, page 2...
# Fetching repositories for tighten, page 3...
# Fetching repositories for rcalix1, page 1...
# Fetching repositories for rcalix1, page 2...
# Fetching repositories for bf4, page 1...
# Fetching repositories for bf4, page 2...
# Fetching repositories for bf4, page 3...
# Fetching repositories for bf4, page 4...
# Fetching repositories for bf4, page 5...
# Fetching repositories for johnwinans, page 1...
# Fetching repositories for johnwinans, page 2...
# Fetching repositories for ryan-haskell, page 1...
# Fetching repositories for ryan-haskell, page 2...
# Fetching repositories for ryan-haskell, page 3...
# Fetching repositories for ryan-haskell, page 4...
# Fetching repositories for Shawn-Shan, page 1...
# Fetching repositories for Shawn-Shan, page 2...
# Fetching repositories for wesleywiser, page 1...
# Fetching repositories for wesleywiser, page 2...
# Fetching repositories for farrukh90, page 1...
# Fetching repositories for farrukh90, page 2...
# Fetching repositories for farrukh90, page 3...
# Fetching repositories for farrukh90, page 4...
# Fetching repositories for farrukh90, page 5...
# Fetching repositories for luisibanez, page 1...
# Fetching repositories for luisibanez, page 2...
# Fetching repositories for luisibanez, page 3...
# Fetching repositories for luisibanez, page 4...
# Fetching repositories for dhermes, page 1...
# Fetching repositories for dhermes, page 2...
# Fetching repositories for dhermes, page 3...
# Fetching repositories for itsjafer, page 1...
# Fetching repositories for itsjafer, page 2...
# Fetching repositories for aekaplan, page 1...
# Fetching repositories for aekaplan, page 2...
# Fetching repositories for simonpcouch, page 1...
# Fetching repositories for simonpcouch, page 2...
# Fetching repositories for tlamadon, page 1...
# Fetching repositories for tlamadon, page 2...
# Fetching repositories for seanchen1991, page 1...
# Fetching repositories for seanchen1991, page 2...
# Fetching repositories for seanchen1991, page 3...
# Fetching repositories for gregwebs, page 1...
# Fetching repositories for gregwebs, page 2...
# Fetching repositories for gregwebs, page 3...
# Fetching repositories for Vadman97, page 1...
# Fetching repositories for Vadman97, page 2...
# Fetching repositories for luizaandrade, page 1...
# Fetching repositories for luizaandrade, page 2...
# Fetching repositories for noootown, page 1...
# Fetching repositories for noootown, page 2...
# Fetching repositories for cdfuller, page 1...
# Fetching repositories for cdfuller, page 2...
# Fetching repositories for ReidCarlberg, page 1...
# Fetching repositories for ReidCarlberg, page 2...
# Fetching repositories for fsadykov, page 1...
# Fetching repositories for fsadykov, page 2...
# Fetching repositories for dkarter, page 1...
# Fetching repositories for dkarter, page 2...
# Fetching repositories for dkarter, page 3...
# Fetching repositories for dkarter, page 4...
# Fetching repositories for chelseatroy, page 1...
# Fetching repositories for chelseatroy, page 2...
# Fetching repositories for chelseatroy, page 3...
# Fetching repositories for masterysystems, page 1...
# Fetching repositories for yyolk, page 1...
# Fetching repositories for yyolk, page 2...
# Fetching repositories for yyolk, page 3...
# Fetching repositories for yyolk, page 4...
# Fetching repositories for yyolk, page 5...
# Fetching repositories for yyolk, page 6...
# Fetching repositories for yyolk, page 7...
# Fetching repositories for yyolk, page 8...
# Fetching repositories for eaton, page 1...
# Fetching repositories for eaton, page 2...
# Fetching repositories for zombor, page 1...
# Fetching repositories for zombor, page 2...
# Fetching repositories for JSH32, page 1...
# Fetching repositories for JSH32, page 2...
# Fetching repositories for ricokahler, page 1...
# Fetching repositories for ricokahler, page 2...
# Fetching repositories for code-for-coffee, page 1...
# Fetching repositories for code-for-coffee, page 2...
# Fetching repositories for code-for-coffee, page 3...
# Fetching repositories for code-for-coffee, page 4...
# Fetching repositories for karlstolley, page 1...
# Fetching repositories for karlstolley, page 2...
# Fetching repositories for wseemann, page 1...
# Fetching repositories for wseemann, page 2...
# Fetching repositories for bhgames, page 1...
# Fetching repositories for bhgames, page 2...
# Fetching repositories for codersquid, page 1...
# Fetching repositories for codersquid, page 2...
# Fetching repositories for braintree, page 1...
# Fetching repositories for braintree, page 2...
# Fetching repositories for dziganto, page 1...
# Fetching repositories for dziganto, page 2...
# Fetching repositories for tollmanz, page 1...
# Fetching repositories for tollmanz, page 2...
# Fetching repositories for tomschenkjr, page 1...
# Fetching repositories for tomschenkjr, page 2...
# Fetching repositories for peterhurford, page 1...
# Fetching repositories for peterhurford, page 2...
# Fetching repositories for joshgav, page 1...
# Fetching repositories for joshgav, page 2...
# Fetching repositories for joshgav, page 3...
# Fetching repositories for kaihoffman, page 1...
# Fetching repositories for kaihoffman, page 2...
# Fetching repositories for stevenmaguire, page 1...
# Fetching repositories for stevenmaguire, page 2...
# Fetching repositories for southpolesteve, page 1...
# Fetching repositories for southpolesteve, page 2...
# Fetching repositories for southpolesteve, page 3...
# Fetching repositories for zackkitzmiller, page 1...
# Fetching repositories for zackkitzmiller, page 2...
# Fetching repositories for zackkitzmiller, page 3...
# Fetching repositories for kevinschaul, page 1...
# Fetching repositories for kevinschaul, page 2...
# Fetching repositories for kevinschaul, page 3...
# Fetching repositories for ryanve, page 1...
# Fetching repositories for ryanve, page 2...
# Fetching repositories for ryanve, page 3...
# Fetching repositories for ryanve, page 4...
# Fetching repositories for jkocherhans, page 1...
# Fetching repositories for jkocherhans, page 2...
# Fetching repositories for ChrisWiegman, page 1...
# Fetching repositories for ChrisWiegman, page 2...
# Fetching repositories for argonne-lcf, page 1...
# Fetching repositories for argonne-lcf, page 2...
# Fetching repositories for argonne-lcf, page 3...
# Fetching repositories for mylo-james, page 1...
# Fetching repositories for mylo-james, page 2...
# Fetching repositories for techtorial, page 1...
# Fetching repositories for techtorial, page 2...
# Fetching repositories for ch33r10, page 1...
# Fetching repositories for ch33r10, page 2...
# Fetching repositories for feamster, page 1...
# Fetching repositories for feamster, page 2...
# Fetching repositories for gregjopa, page 1...
# Fetching repositories for gregjopa, page 2...
# Fetching repositories for jeffpaul, page 1...
# Fetching repositories for jeffpaul, page 2...
# Fetching repositories for johnagan, page 1...
# Fetching repositories for johnagan, page 2...
# Fetching repositories for asajeffrey, page 1...
# Fetching repositories for asajeffrey, page 2...
# Fetching repositories for muratkeremozcan, page 1...
# Fetching repositories for muratkeremozcan, page 2...
# Fetching repositories for muratkeremozcan, page 3...
# Fetching repositories for skriegman, page 1...
# Fetching repositories for skriegman, page 2...
# Fetching repositories for newville, page 1...
# Fetching repositories for newville, page 2...
# Fetching repositories for karbassi, page 1...
# Fetching repositories for karbassi, page 2...
# Fetching repositories for karbassi, page 3...
# Fetching repositories for karbassi, page 4...
# Fetching repositories for karbassi, page 5...
# Fetching repositories for cooperlees, page 1...
# Fetching repositories for cooperlees, page 2...
# Fetching repositories for dvtate, page 1...
# Fetching repositories for dvtate, page 2...
# Fetching repositories for deanmalmgren, page 1...
# Fetching repositories for deanmalmgren, page 2...
# Fetching repositories for marwahaha, page 1...
# Fetching repositories for marwahaha, page 2...
# Fetching repositories for marwahaha, page 3...
# Fetching repositories for marwahaha, page 4...
# Fetching repositories for marwahaha, page 5...
# Fetching repositories for marwahaha, page 6...
# Fetching repositories for marwahaha, page 7...
# Fetching repositories for marwahaha, page 8...
# Fetching repositories for marwahaha, page 9...
# Fetching repositories for marwahaha, page 10...
# Fetching repositories for marwahaha, page 11...
# Fetching repositories for marwahaha, page 12...
# Fetching repositories for marwahaha, page 13...
# Fetching repositories for borjasotomayor, page 1...
# Fetching repositories for borjasotomayor, page 2...
# Fetching repositories for bangpound, page 1...
# Fetching repositories for bangpound, page 2...
# Fetching repositories for bangpound, page 3...
# Fetching repositories for bangpound, page 4...
# Fetching repositories for bangpound, page 5...
# Fetching repositories for luisdomin5, page 1...
# Fetching repositories for luisdomin5, page 2...
# Fetching repositories for luisdomin5, page 3...
# Fetching repositories for luisdomin5, page 4...
# Fetching repositories for luisdomin5, page 5...
# Fetching repositories for luisdomin5, page 6...
# Fetching repositories for ming024, page 1...
# Fetching repositories for ming024, page 2...
# Fetching repositories for adamgraham, page 1...
# Fetching repositories for adamgraham, page 2...
# Fetching repositories for nixpad, page 1...
# Fetching repositories for nixpad, page 2...
# Fetching repositories for cr0ybot, page 1...
# Fetching repositories for cr0ybot, page 2...
# Fetching repositories for gfredericks, page 1...
# Fetching repositories for gfredericks, page 2...
# Fetching repositories for gfredericks, page 3...
# Fetching repositories for kfogel, page 1...
# Fetching repositories for kfogel, page 2...
# Fetching repositories for thereals0beit, page 1...
# Fetching repositories for thereals0beit, page 2...
# Fetching repositories for DebeshJha, page 1...
# Fetching repositories for DebeshJha, page 2...
# Fetching repositories for DataSolveProblems, page 1...
# Fetching repositories for DataSolveProblems, page 2...
# Fetching repositories for technobly, page 1...
# Fetching repositories for technobly, page 2...
# Fetching repositories for technobly, page 3...
# Fetching repositories for KazukiPrzyborowski, page 1...
# Fetching repositories for KazukiPrzyborowski, page 2...
# Fetching repositories for AgentK20, page 1...
# Fetching repositories for AgentK20, page 2...
# Fetching repositories for aerosoul94, page 1...
# Fetching repositories for aerosoul94, page 2...
# Fetching repositories for safe-graph, page 1...
# Fetching repositories for safe-graph, page 2...
# Fetching repositories for benstr, page 1...
# Fetching repositories for benstr, page 2...
# Fetching repositories for relativityone, page 1...
# Fetching repositories for relativityone, page 2...
# Fetching repositories for Aeva, page 1...
# Fetching repositories for Aeva, page 2...
# Fetching repositories for JustinMShea, page 1...
# Fetching repositories for JustinMShea, page 2...
# Fetching repositories for pyro2927, page 1...
# Fetching repositories for pyro2927, page 2...
# Fetching repositories for pyro2927, page 3...
# Fetching repositories for klaeufer, page 1...
# Fetching repositories for klaeufer, page 2...
# Fetching repositories for adomokos, page 1...
# Fetching repositories for adomokos, page 2...
# Fetching repositories for monsur, page 1...
# Fetching repositories for monsur, page 2...
# Fetching repositories for scollis, page 1...
# Fetching repositories for scollis, page 2...
# Fetching repositories for scollis, page 3...
# Fetching repositories for scollis, page 4...
# Fetching repositories for spjeff, page 1...
# Fetching repositories for spjeff, page 2...
# Fetching repositories for nicholas-ochoa, page 1...
# Fetching repositories for nicholas-ochoa, page 2...
# Fetching repositories for arelia, page 1...
# Fetching repositories for arelia, page 2...
# Fetching repositories for Sc00bz, page 1...
# Fetching repositories for Sc00bz, page 2...
# Fetching repositories for wimglenn, page 1...
# Fetching repositories for wimglenn, page 2...
# Fetching repositories for wimglenn, page 3...
# Fetching repositories for datamade, page 1...
# Fetching repositories for datamade, page 2...
# Fetching repositories for datamade, page 3...
# Fetching repositories for datamade, page 4...
# Fetching repositories for zekenie, page 1...
# Fetching repositories for zekenie, page 2...
# Fetching repositories for PedroLopes, page 1...
# Fetching repositories for PedroLopes, page 2...
# Fetching repositories for carolineartz, page 1...
# Fetching repositories for carolineartz, page 2...
# Fetching repositories for carolineartz, page 3...
# Fetching repositories for destefanis, page 1...
# Fetching repositories for destefanis, page 2...
# Fetching repositories for exrlla, page 1...
# Fetching repositories for exrlla, page 2...
# Fetching repositories for robertzk, page 1...
# Fetching repositories for robertzk, page 2...
# Fetching repositories for robertzk, page 3...
# Fetching repositories for joshbeckman, page 1...
# Fetching repositories for joshbeckman, page 2...
# Fetching repositories for joshbeckman, page 3...
# Fetching repositories for narcisolobo, page 1...
# Fetching repositories for narcisolobo, page 2...
# Fetching repositories for narcisolobo, page 3...
# Fetching repositories for narcisolobo, page 4...
# Fetching repositories for EricKuck, page 1...
# Fetching repositories for EricKuck, page 2...
# Fetching repositories for michaelstonis, page 1...
# Fetching repositories for michaelstonis, page 2...
# Fetching repositories for JeffCohen, page 1...
# Fetching repositories for JeffCohen, page 2...
# Fetching repositories for stephen-hoover, page 1...
# Fetching repositories for stephen-hoover, page 2...
# Fetching repositories for baldengineer, page 1...
# Fetching repositories for baldengineer, page 2...
# Fetching repositories for pcarbo, page 1...
# Fetching repositories for pcarbo, page 2...
# Fetching repositories for sc1341, page 1...
# Fetching repositories for sc1341, page 2...
# Fetching repositories for gaojunxuan, page 1...
# Fetching repositories for gaojunxuan, page 2...
# Fetching repositories for jim, page 1...
# Fetching repositories for jim, page 2...
# Fetching repositories for mqudsi, page 1...
# Fetching repositories for mqudsi, page 2...
# Fetching repositories for mqudsi, page 3...
# Fetching repositories for eigenhombre, page 1...
# Fetching repositories for eigenhombre, page 2...
# Fetching repositories for eigenhombre, page 3...
# Fetching repositories for jmercouris, page 1...
# Fetching repositories for jmercouris, page 2...
# Fetching repositories for rathjenc, page 1...
# Fetching repositories for rathjenc, page 2...
# Fetching repositories for Interbotix, page 1...
# Fetching repositories for Interbotix, page 2...
# Fetching repositories for patrickfuller, page 1...
# Fetching repositories for patrickfuller, page 2...
# Fetching repositories for gkthiruvathukal, page 1...
# Fetching repositories for gkthiruvathukal, page 2...
# Fetching repositories for gkthiruvathukal, page 3...
# Fetching repositories for chicago-joe, page 1...
# Fetching repositories for chicago-joe, page 2...
# Fetching repositories for chicago-joe, page 3...
# Fetching repositories for donthedeveloper, page 1...
# Fetching repositories for donthedeveloper, page 2...
# Fetching repositories for cdipaolo, page 1...
# Fetching repositories for cdipaolo, page 2...
# Fetching repositories for Kaushal1011, page 1...
# Fetching repositories for Kaushal1011, page 2...
# Fetching repositories for zurmo, page 1...
# Fetching repositories for zurmo, page 2...
# Fetching repositories for rmw, page 1...
# Fetching repositories for rmw, page 2...
# Fetching repositories for jvz, page 1...
# Fetching repositories for jvz, page 2...
# Fetching repositories for jvz, page 3...
# Fetching repositories for azaa1, page 1...
# Fetching repositories for azaa1, page 2...
# Fetching repositories for hugofloresgarcia, page 1...
# Fetching repositories for hugofloresgarcia, page 2...
# Fetching repositories for larsbergstrom, page 1...
# Fetching repositories for larsbergstrom, page 2...
# Fetching repositories for allscriptshealthcare, page 1...
# Fetching repositories for abaker, page 1...
# Fetching repositories for abaker, page 2...
# Fetching repositories for glowcoil, page 1...
# Fetching repositories for glowcoil, page 2...
# Fetching repositories for bitcraft, page 1...
# Fetching repositories for bitcraft, page 2...
# Fetching repositories for eguevara, page 1...
# Fetching repositories for eguevara, page 2...
# Fetching repositories for shanesveller, page 1...
# Fetching repositories for shanesveller, page 2...
# Fetching repositories for blakesmith, page 1...
# Fetching repositories for blakesmith, page 2...
# Fetching repositories for blakesmith, page 3...
# Fetching repositories for SteveMcGrath, page 1...
# Fetching repositories for SteveMcGrath, page 2...
# Fetching repositories for curtgrimes, page 1...
# Fetching repositories for curtgrimes, page 2...
# Fetching repositories for rudyrigot, page 1...
# Fetching repositories for rudyrigot, page 2...
# Fetching repositories for michel-slm, page 1...
# Fetching repositories for michel-slm, page 2...
# Fetching repositories for michel-slm, page 3...
# Fetching repositories for michel-slm, page 4...
# Fetching repositories for seanwu1105, page 1...
# Fetching repositories for seanwu1105, page 2...
# Fetching repositories for NicholeKing, page 1...
# Fetching repositories for NicholeKing, page 2...
# Fetching repositories for bensoltoff, page 1...
# Fetching repositories for bensoltoff, page 2...
# Fetching repositories for patrickxb, page 1...
# Fetching repositories for patrickxb, page 2...
# Fetching repositories for Summair, page 1...
# Fetching repositories for Summair, page 2...
# Fetching repositories for gauss1181, page 1...
# Fetching repositories for gauss1181, page 2...
# Fetching repositories for DavidJFelix, page 1...
# Fetching repositories for DavidJFelix, page 2...
# Fetching repositories for y-x-c, page 1...
# Fetching repositories for y-x-c, page 2...
# Fetching repositories for chicagocomputerclasses, page 1...
# Fetching repositories for chicagocomputerclasses, page 2...
# Fetching repositories for gennyble, page 1...
# Fetching repositories for gennyble, page 2...
# Fetching repositories for lukehoersten, page 1...
# Fetching repositories for lukehoersten, page 2...
# Fetching repositories for Chicago, page 1...
# Fetching repositories for Chicago, page 2...
# Fetching repositories for alainakafkes, page 1...
# Fetching repositories for alainakafkes, page 2...
# Fetching repositories for piemadd, page 1...
# Fetching repositories for piemadd, page 2...
# Fetching repositories for piemadd, page 3...
# Fetching repositories for b-meson, page 1...
# Fetching repositories for b-meson, page 2...
# Fetching repositories for evbogue, page 1...
# Fetching repositories for evbogue, page 2...
# Fetching repositories for coolreader18, page 1...
# Fetching repositories for coolreader18, page 2...
# Fetching repositories for coolreader18, page 3...
# Fetching repositories for coolreader18, page 4...
# Fetching repositories for jwieting, page 1...
# Fetching repositories for jwieting, page 2...
# Fetching repositories for calchulus, page 1...
# Fetching repositories for calchulus, page 2...
# Fetching repositories for calchulus, page 3...
# Fetching repositories for calchulus, page 4...
# Fetching repositories for calchulus, page 5...
# Fetching repositories for calchulus, page 6...
# Fetching repositories for heitortsergent, page 1...
# Fetching repositories for heitortsergent, page 2...
# Fetching repositories for christophermanning, page 1...
# Fetching repositories for christophermanning, page 2...
# Fetching repositories for rsinger86, page 1...
# Fetching repositories for rsinger86, page 2...
# Fetching repositories for noelrappin, page 1...
# Fetching repositories for noelrappin, page 2...
# Fetching repositories for kvnkho, page 1...
# Fetching repositories for kvnkho, page 2...
# Fetching repositories for ivanfemia, page 1...
# Fetching repositories for ivanfemia, page 2...
# Fetching repositories for SarahMAmann, page 1...
# Fetching repositories for SarahMAmann, page 2...
# Fetching repositories for zircote, page 1...
# Fetching repositories for zircote, page 2...
# Fetching repositories for sonamoo, page 1...
# Fetching repositories for sonamoo, page 2...
# Fetching repositories for sleventyeleven, page 1...
# Fetching repositories for sleventyeleven, page 2...
# Fetching repositories for mgrygles, page 1...
# Fetching repositories for mgrygles, page 2...
# Fetching repositories for rossb34, page 1...
# Fetching repositories for rossb34, page 2...
# Fetching repositories for stamourv, page 1...
# Fetching repositories for stamourv, page 2...
# Fetching repositories for stamourv, page 3...
# Fetching repositories for loucyx, page 1...
# Fetching repositories for loucyx, page 2...
# Fetching repositories for alexlyp, page 1...
# Fetching repositories for alexlyp, page 2...
# Fetching repositories for deanrad, page 1...
# Fetching repositories for deanrad, page 2...
# Fetching repositories for deanrad, page 3...
# Fetching repositories for deanrad, page 4...
# Fetching repositories for brianray, page 1...
# Fetching repositories for brianray, page 2...
# Fetching repositories for skirmer, page 1...
# Fetching repositories for skirmer, page 2...
# Fetching repositories for barelyknown, page 1...
# Fetching repositories for barelyknown, page 2...
# Fetching repositories for agfor, page 1...
# Fetching repositories for agfor, page 2...
# Fetching repositories for rsutphin, page 1...
# Fetching repositories for rsutphin, page 2...
# Fetching repositories for snowgy, page 1...
# Fetching repositories for snowgy, page 2...
# Fetching repositories for ksolo, page 1...
# Fetching repositories for ksolo, page 2...
# Fetching repositories for ksolo, page 3...
# Fetching repositories for defaultxr, page 1...
# Fetching repositories for defaultxr, page 2...
# Fetching repositories for stevepopovich, page 1...
# Fetching repositories for stevepopovich, page 2...
# Fetching repositories for andymboyle, page 1...
# Fetching repositories for andymboyle, page 2...
# Fetching repositories for jdoss, page 1...
# Fetching repositories for jdoss, page 2...
# Fetching repositories for SpezialK71, page 1...
# Fetching repositories for SpezialK71, page 2...
# Fetching repositories for shonumi, page 1...
# Fetching repositories for shonumi, page 2...
# Fetching repositories for maggiewolff, page 1...
# Fetching repositories for maggiewolff, page 2...
# Fetching repositories for anthonyleezhang, page 1...
# Fetching repositories for anthonyleezhang, page 2...
# Fetching repositories for daisyUniverse, page 1...
# Fetching repositories for daisyUniverse, page 2...
# Fetching repositories for maxmiller413, page 1...
# Fetching repositories for maxmiller413, page 2...
# Fetching repositories for maxmiller413, page 3...
# Fetching repositories for maxmiller413, page 4...
# Fetching repositories for glitchfur, page 1...
# Fetching repositories for glitchfur, page 2...
# Fetching repositories for meltingscales, page 1...
# Fetching repositories for meltingscales, page 2...
# Fetching repositories for meltingscales, page 3...
# Fetching repositories for meltingscales, page 4...
# Fetching repositories for meltingscales, page 5...
# Fetching repositories for wmurphyrd, page 1...
# Fetching repositories for wmurphyrd, page 2...
# Fetching repositories for CodyNicholson, page 1...
# Fetching repositories for CodyNicholson, page 2...
# Fetching repositories for CodyNicholson, page 3...
# Fetching repositories for mgrover1, page 1...
# Fetching repositories for mgrover1, page 2...
# Fetching repositories for mgrover1, page 3...
# Fetching repositories for KovasMcCann, page 1...
# Fetching repositories for KovasMcCann, page 2...
# Fetching repositories for csantiago132, page 1...
# Fetching repositories for csantiago132, page 2...
# Fetching repositories for jaku, page 1...
# Fetching repositories for jaku, page 2...
# Fetching repositories for AbrarSyed, page 1...
# Fetching repositories for AbrarSyed, page 2...
# Fetching repositories for juneau001, page 1...
# Fetching repositories for juneau001, page 2...
# Fetching repositories for alycit, page 1...
# Fetching repositories for alycit, page 2...
# Fetching repositories for mstratman, page 1...
# Fetching repositories for mstratman, page 2...
# Fetching repositories for CaryLandholt, page 1...
# Fetching repositories for CaryLandholt, page 2...
# Fetching repositories for knagaitsev, page 1...
# Fetching repositories for knagaitsev, page 2...
# Fetching repositories for omargfh, page 1...
# Fetching repositories for omargfh, page 2...
# Fetching repositories for RonaldColyar, page 1...
# Fetching repositories for RonaldColyar, page 2...
# Fetching repositories for erichilarysmithsr, page 1...
# Fetching repositories for erichilarysmithsr, page 2...
# Fetching repositories for erichilarysmithsr, page 3...
# Fetching repositories for erichilarysmithsr, page 4...
# Fetching repositories for erichilarysmithsr, page 5...
# Fetching repositories for erichilarysmithsr, page 6...
# Fetching repositories for erichilarysmithsr, page 7...
# Fetching repositories for luoyuanlab, page 1...
# Fetching repositories for luoyuanlab, page 2...
# Fetching repositories for jfnavarro21, page 1...
# Fetching repositories for jfnavarro21, page 2...
# Fetching repositories for rlk, page 1...
# Fetching repositories for rlk, page 2...
# Fetching repositories for 3CloudSolutions, page 1...
# Fetching repositories for 3CloudSolutions, page 2...
# Fetching repositories for cwarden, page 1...
# Fetching repositories for cwarden, page 2...
# Fetching repositories for cwarden, page 3...
# Fetching repositories for cwarden, page 4...
# Fetching repositories for nadrane, page 1...
# Fetching repositories for nadrane, page 2...
# Fetching repositories for rogeruiz, page 1...
# Fetching repositories for rogeruiz, page 2...
# Fetching repositories for rogeruiz, page 3...
# Fetching repositories for scottferg, page 1...
# Fetching repositories for scottferg, page 2...
# Fetching repositories for jebeck, page 1...
# Fetching repositories for jebeck, page 2...
# Saved users.csv successfully!
# Saved repositories.csv successfully!
# README.md created successfully!

# %%
import pandas as pd

# Load the CSV files
users_df = pd.read_csv("users.csv")
repos_df = pd.read_csv("repositories.csv")

# Display the first few rows to understand the structure
print(users_df.head())
print(repos_df.head())
# Out:
#          login  name  company  location  email  hireable  bio  public_repos  \
# 0     cassidoo   NaN      NaN       NaN    NaN       NaN  NaN             0
# 1     felangel   NaN      NaN       NaN    NaN       NaN  NaN             0
# 2       dabeaz   NaN      NaN       NaN    NaN       NaN  NaN             0
# 3  sstephenson   NaN      NaN       NaN    NaN       NaN  NaN             0
# 4  mattgodbolt   NaN      NaN       NaN    NaN       NaN  NaN             0
#
#    followers  following  created_at
# 0          0          0         NaN
# 1          0          0         NaN
# 2          0          0         NaN
# 3          0          0         NaN
# 4          0          0         NaN
#       login           full_name            created_at  stargazers_count  \
# 0  cassidoo  cassidoo/accordion  2020-01-23T13:19:32Z                17
# 1  cassidoo      cassidoo/agagd  2023-11-20T05:21:51Z                 1
# 2  cassidoo        cassidoo/ama  2020-06-09T02:22:18Z                62
# 3  cassidoo    cassidoo/ASL2048  2014-03-20T14:29:23Z                 0
# 4  cassidoo      cassidoo/astro  2021-09-14T06:35:07Z                 0
#
#    watchers_count    language  has_projects  has_wiki license_name
# 0              17  JavaScript          True      True          NaN
# 1               1         NaN          True     False          mit
# 2              62         NaN         False     False          NaN
# 3               0         CSS          True      True          mit
# 4               0         NaN          True     False        other

# %%
top_5_followers = users_df.sort_values(by='followers', ascending=False).head(5)
print(",".join(top_5_followers['login']))
# Out:
# cassidoo,scollis,carolineartz,PedroLopes,zekenie

# %%
earliest_users = users_df.sort_values(by='created_at').head(5)
print(",".join(earliest_users['login']))
# Out:
# cassidoo,felangel,dabeaz,sstephenson,mattgodbolt

# %%
licenses = repos_df['license_name'].dropna()
top_3_licenses = licenses.value_counts().head(3).index
print(",".join(top_3_licenses))
# Out:
# mit,gpl-3.0,other

# %%
#
most_common_company = cleaned_companies.value_counts().idxmax()
print(f"The most common company is: {most_common_company}")
# Out:
# The most common company is:

# %%
most_popular_language = repos_df['language'].mode()[0]
print(most_popular_language)
# Out:
# JavaScript

# %%
users_after_2020 = users_df[users_df['created_at'] >= '2020-01-01']
repos_after_2020 = repos_df[repos_df['login'].isin(users_after_2020['login'])]
second_popular_language = repos_after_2020['language'].value_counts().index[1]
print(second_popular_language)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 users_after_2020 = users_df[users_df['created_at'] >= '2020-01-01']
#       2 repos_after_2020 = repos_df[repos_df['login'].isin(users_after_2020['login'])]
#       3 second_popular_language = repos_after_2020['language'].value_counts().index[1]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:341, in comparison_op(left, right, op)
#     337         res_values = np.zeros(lvalues.shape, dtype=bool)
#     339 elif is_numeric_v_string_like(lvalues, rvalues):
#     340     # GH#36377 going through the numexpr path would incorrectly raise
# --> 341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
#     344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\invalid.py:40, in invalid_comparison(left, right, op)
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=float64 and str

# %%
avg_stars = repos_df.groupby('language')['stargazers_count'].mean().idxmax()
print(avg_stars)
# Out:
# Vim Script

# %%
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])
top_5_leader_strength = users_df.sort_values(by='leader_strength', ascending=False).head(5)
print(",".join(top_5_leader_strength['login']))
# Out:
# cassidoo,scollis,carolineartz,PedroLopes,zekenie

# %%
correlation = users_df['followers'].corr(users_df['public_repos'])
print(f"{correlation:.3f}")
# Out:
# nan
# C:\Users\Devansh Shukla\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]

# %%
from scipy.stats import linregress

slope, intercept, r_value, p_value, std_err = linregress(users_df['public_repos'], users_df['followers'])
print(f"{slope:.3f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25900\3328176799.py in ?()
#       1 from scipy.stats import linregress
#       2
# ----> 3 slope, intercept, r_value, p_value, std_err = linregress(users_df['public_repos'], users_df['followers'])
#       4 print(f"{slope:.3f}")
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_stats_py.py in ?(x, y, alternative)
#   10890     if x.size == 0 or y.size == 0:
#   10891         raise ValueError("Inputs must not be empty.")
#   10892
#   10893     if np.amax(x) == np.amin(x) and len(x) > 1:
# > 10894         raise ValueError("Cannot calculate a linear regression "
#   10895                          "if all x values are identical")
#   10896
#   10897     n = len(x)
#
# ValueError: Cannot calculate a linear regression if all x values are identical

# %%
projects_wiki_corr = repos_df['has_projects'].corr(repos_df['has_wiki'])
print(f"{projects_wiki_corr:.3f}")
# Out:
# 0.285

# %%
hireable_following = users_df[users_df['hireable'] == "true"]['following'].mean()
non_hireable_following = users_df[users_df['hireable'] != "true"]['following'].mean()
print(f"{(hireable_following - non_hireable_following):.3f}")
# Out:
# nan

# %%
users_df['bio_word_count'] = users_df['bio'].fillna("").apply(lambda x: len(x.split()))
bio_slope, _, _, _, _ = linregress(users_df['bio_word_count'], users_df['followers'])
print(f"{bio_slope:.3f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25900\246072779.py in ?()
#       1 users_df['bio_word_count'] = users_df['bio'].fillna("").apply(lambda x: len(x.split()))
# ----> 2 bio_slope, _, _, _, _ = linregress(users_df['bio_word_count'], users_df['followers'])
#       3 print(f"{bio_slope:.3f}")
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_stats_py.py in ?(x, y, alternative)
#   10890     if x.size == 0 or y.size == 0:
#   10891         raise ValueError("Inputs must not be empty.")
#   10892
#   10893     if np.amax(x) == np.amin(x) and len(x) > 1:
# > 10894         raise ValueError("Cannot calculate a linear regression "
#   10895                          "if all x values are identical")
#   10896
#   10897     n = len(x)
#
# ValueError: Cannot calculate a linear regression if all x values are identical

# %%
repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])
repos_df['weekday'] = repos_df['created_at'].dt.weekday  # 5 = Saturday, 6 = Sunday
weekend_repos = repos_df[repos_df['weekday'].isin([5, 6])]
most_repos_weekend_user = weekend_repos['login'].value_counts().head(5)
print(",".join(most_repos_weekend_user.index))
# Out:
# marwahaha,austinsonger,eddelbuettel,erichilarysmithsr,yyolk

# %%
hireable_with_email = users_df[(users_df['hireable'] == "true") & (users_df['email'].notna())].shape[0]
non_hireable_with_email = users_df[(users_df['hireable'] != "true") & (users_df['email'].notna())].shape[0]

hireable_fraction = hireable_with_email / users_df[users_df['hireable'] == "true"].shape[0]
non_hireable_fraction = non_hireable_with_email / users_df[users_df['hireable'] != "true"].shape[0]
print(f"{(hireable_fraction - non_hireable_fraction):.3f}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[22], line 4
#       1 hireable_with_email = users_df[(users_df['hireable'] == "true") & (users_df['email'].notna())].shape[0]
#       2 non_hireable_with_email = users_df[(users_df['hireable'] != "true") & (users_df['email'].notna())].shape[0]
# ----> 4 hireable_fraction = hireable_with_email / users_df[users_df['hireable'] == "true"].shape[0]
#       5 non_hireable_fraction = non_hireable_with_email / users_df[users_df['hireable'] != "true"].shape[0]
#       6 print(f"{(hireable_fraction - non_hireable_fraction):.3f}")
#
# ZeroDivisionError: division by zero

# %%
def extract_last_name(name):
    if pd.isna(name) or not name.strip():
        return None
    return name.strip().split()[-1]

users_df['last_name'] = users_df['name'].apply(extract_last_name)
most_common_surname = users_df['last_name'].value_counts().head(1).index[0]
print(most_common_surname)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 7
#       4     return name.strip().split()[-1]
#       6 users_df['last_name'] = users_df['name'].apply(extract_last_name)
# ----> 7 most_common_surname = users_df['last_name'].value_counts().head(1).index[0]
#       8 print(most_common_surname)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
#    5392     # This case is separated from the conditional above to avoid
#    5393     # pessimization com.is_bool_indexer and ndim checks.
#    5394     return self._getitem_slice(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
